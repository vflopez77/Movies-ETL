# %%
import pandas as pd

# %%
movies_metadata = pd.read_csv('movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('ratings.csv')

# %%
movies_metadata.sample(n=5)
# Out:
#        adult belongs_to_collection budget  \
# 36602  False                   NaN      0
# 35473  False                   NaN      0
# 6500   False                   NaN      0
# 16840  False                   NaN      0
# 34636  False                   NaN      0
#
#                                                   genres  \
# 36602  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 35473                     [{'id': 35, 'name': 'Comedy'}]
# 6500                       [{'id': 18, 'name': 'Drama'}]
# 16840  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 34636                      [{'id': 18, 'name': 'Drama'}]
#
#                    homepage      id    imdb_id original_language  \
# 36602                   NaN  347847  tt3399484                en
# 35473  http://phdmovie.com/  373976  tt4779296                en
# 6500                    NaN   43048  tt0054412                en
# 16840                   NaN   93528  tt0051193                en
# 34636                   NaN  134155  tt0006895                en
#
#          original_title                                           overview  \
# 36602          The Sand  Just when you thought it was safe to go back i...
# 35473   The PHD Movie 2  The Nameless Grad Student and his group must t...
# 6500     Tunes of Glory  Major Jock Sinclair has been in this Highland ...
# 16840  Wild Is the Wind  Wild Is the Wind represents a (perhaps deliber...
# 34636         King Lear       Silent adaptation of Shakespeare's King Lear
#
#        ... release_date revenue runtime  \
# 36602  ...   2015-08-28     0.0    84.0
# 35473  ...   2015-12-23     0.0    82.0
# 6500   ...   1960-08-16     0.0   102.0
# 16840  ...   1957-12-11     0.0   114.0
# 34636  ...   1916-12-17     0.0    63.0
#
#                                         spoken_languages    status  \
# 36602           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 35473           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6500            [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 16840  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 34636                                                 []  Released
#
#                                               tagline             title  \
# 36602                            This Beach is Killer          The Sand
# 35473                            Still in Grad School   The PHD Movie 2
# 6500   Here's a Helluva Swelluva Free-Swinging Movie!    Tunes of Glory
# 16840                                             NaN  Wild Is the Wind
# 34636                                             NaN         King Lear
#
#        video vote_average vote_count
# 36602  False          3.8       29.0
# 35473  False          0.0        0.0
# 6500   False          7.1       14.0
# 16840  False          7.2        3.0
# 34636  False          2.5        2.0
#
# [5 rows x 24 columns]

# %%
ratings.sample(n=5)
# Out:
#           userId  movieId  rating   timestamp
# 7532997    77749      940     4.0   857990755
# 6139982    63264      194     4.0   938976673
# 24966477  259615     1213     5.0  1439801209
# 15932917  165751      653     4.0   861126602
# 24688477  256634     2321     3.5  1095469735

# %%
square = lambda x: x * x
square(5)
# Out:
# 25
